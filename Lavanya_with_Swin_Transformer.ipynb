# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanyasatpute/lavanyasatpute/blob/main/Lavanya_with_Swin_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import Dense, LayerNormalization, Dropout

# class WindowAttention(tf.keras.layers.Layer):
#     def __init__(self, dim, num_heads, window_size, **kwargs):
#         super(WindowAttention, self).__init__(**kwargs)
#         self.dim = dim
#         self.num_heads = num_heads
#         self.window_size = window_size
#         self.scale = (dim // num_heads) ** -0.5
#         self.query_dense = Dense(dim)
#         self.key_dense = Dense(dim)
#         self.value_dense = Dense(dim)
#         self.proj = Dense(dim)

#     def call(self, x):
#         B, N, C = x.shape  # Batch, Num tokens, Channels
#         q = self.query_dense(x)
#         k = self.key_dense(x)
#         v = self.value_dense(x)

#         # Split heads for multi-head attention
#         q = tf.reshape(q, (B, N, self.num_heads, C // self.num_heads))
#         k = tf.reshape(k, (B, N, self.num_heads, C // self.num_heads))
#         v = tf.reshape(v, (B, N, self.num_heads, C // self.num_heads))

#         # Scaled dot-product attention
#         attn = tf.einsum('bnqd,bnkd->bnqk', q, k) * self.scale
#         attn = tf.nn.softmax(attn, axis=-1)
#         attn_output = tf.einsum('bnqk,bnvd->bnqd', attn, v)

#         # Combine heads and project
#         attn_output = tf.reshape(attn_output, (B, N, C))
#         x = self.proj(attn_output)
#         return x

# class SwinTransformerBlock(tf.keras.layers.Layer):
#     def __init__(self, dim, num_heads, window_size, input_resolution, shift_size=0, mlp_ratio=4., dropout_rate=0.0, **kwargs):
#         super(SwinTransformerBlock, self).__init__(**kwargs)
#         self.dim = dim
#         self.num_heads = num_heads
#         self.window_size = window_size
#         self.input_resolution = input_resolution
#         self.shift_size = shift_size
#         self.mlp_ratio = mlp_ratio

#         self.norm1 = LayerNormalization(epsilon=1e-5)
#         self.attn = WindowAttention(dim, num_heads, window_size)

#         self.drop_path = Dropout(dropout_rate)
#         self.norm2 = LayerNormalization(epsilon=1e-5)

#         self.mlp = tf.keras.Sequential([
#             Dense(int(dim * mlp_ratio), activation='gelu'),
#             Dropout(dropout_rate),
#             Dense(dim),
#             Dropout(dropout_rate)
#         ])

#     def call(self, x):
#         H, W = self.input_resolution
#         B, L, C = x.shape
#         assert L == H * W, "Input feature has wrong size"

#         shortcut = x
#         x = self.norm1(x)
#         x = tf.reshape(x, (B, H, W, C))

#         # Cyclic shift for SW-MSA
#         if self.shift_size > 0:
#             shifted_x = tf.roll(x, shift=[-self.shift_size, -self.shift_size], axis=[1, 2])
#         else:
#             shifted_x = x

#         # Partition windows
#         x_windows = tf.image.extract_patches(
#             images=shifted_x,
#             sizes=[1, self.window_size, self.window_size, 1],
#             strides=[1, self.window_size, self.window_size, 1],
#             rates=[1, 1, 1, 1],
#             padding="VALID",
#         )
#         x_windows = tf.reshape(x_windows, (-1, self.window_size * self.window_size, C))

#         # Window-based self-attention
#         attn_windows = self.attn(x_windows)

#         # Merge windows back to original size
#         attn_windows = tf.reshape(attn_windows, (-1, H // self.window_size, W // self.window_size, self.window_size, self.window_size, C))
#         shifted_x = tf.reshape(attn_windows, (B, H, W, C))

#         # Reverse cyclic shift if shifted
#         if self.shift_size > 0:
#             x = tf.roll(shifted_x, shift=[self.shift_size, self.shift_size], axis=[1, 2])
#         else:
#             x = shifted_x

#         x = tf.reshape(x, (B, H * W, C))

#         # Residual connection and MLP
#         x = shortcut + self.drop_path(x)
#         x = x + self.drop_path(self.mlp(self.norm2(x)))
#         return x

# %%
# class SwinTransformerBlock(tf.keras.layers.Layer):
#     def __init__(self, dim, num_heads, window_size, input_resolution, shift_size=0, mlp_ratio=4., dropout_rate=0.0, **kwargs):
#         super(SwinTransformerBlock, self).__init__(**kwargs)
#         self.dim = dim
#         self.num_heads = num_heads
#         self.window_size = window_size
#         self.input_resolution = input_resolution
#         self.shift_size = shift_size
#         self.mlp_ratio = mlp_ratio

#         self.norm1 = LayerNormalization(epsilon=1e-5)
#         self.attn = WindowAttention(dim, num_heads, window_size)

#         self.drop_path = Dropout(dropout_rate)
#         self.norm2 = LayerNormalization(epsilon=1e-5)

#         self.mlp = tf.keras.Sequential([
#             Dense(int(dim * mlp_ratio), activation='gelu'),
#             Dropout(dropout_rate),
#             Dense(dim),
#             Dropout(dropout_rate)
#         ])

#     def call(self, x):
#         H, W = self.input_resolution
#         B, L, C = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]  # Dynamically get shapes
#         assert L == H * W, "Input feature has wrong size"

#         shortcut = x
#         x = self.norm1(x)

#         # Reshape x dynamically
#         x = tf.reshape(x, (B, H, W, C))

#         # Apply cyclic shift if shift_size > 0 using tf.cond
#         shifted_x = tf.cond(
#             tf.math.greater(self.shift_size, 0),
#             lambda: tf.roll(x, shift=[-self.shift_size, -self.shift_size], axis=[1, 2]),
#             lambda: x
#         )

#         # Partition windows
#         x_windows = tf.image.extract_patches(
#             images=shifted_x,
#             sizes=[1, self.window_size, self.window_size, 1],
#             strides=[1, self.window_size, self.window_size, 1],
#             rates=[1, 1, 1, 1],
#             padding="VALID",
#         )
#         x_windows = tf.reshape(x_windows, (-1, self.window_size * self.window_size, C))

#         # Window-based self-attention
#         attn_windows = self.attn(x_windows)

#         # Merge windows back to original size
#         attn_windows = tf.reshape(attn_windows, (-1, H // self.window_size, W // self.window_size, self.window_size, self.window_size, C))
#         shifted_x = tf.reshape(attn_windows, (B, H, W, C))

#         # Reverse cyclic shift if shifted, using tf.cond
#         x = tf.cond(
#             tf.math.greater(self.shift_size, 0),
#             lambda: tf.roll(shifted_x, shift=[self.shift_size, self.shift_size], axis=[1, 2]),
#             lambda: shifted_x
#         )

#         # Flatten back to (B, L, C)
#         x = tf.reshape(x, (B, H * W, C))

#         # Residual connection and MLP
#         x = shortcut + self.drop_path(x)
#         x = x + self.drop_path(self.mlp(self.norm2(x)))
#         return x

# %%
# import tensorflow as tf
# from tensorflow.keras.layers import Input, Dense, Conv2D, Reshape, UpSampling2D, Conv2DTranspose
# from tensorflow.keras.applications import ResNet50
# from tensorflow.keras.models import Model

# # Assuming PatchMerging and SwinTransformerBlock are already defined in the code

# class PatchMerging(tf.keras.layers.Layer):
#     def __init__(self, input_resolution, dim, **kwargs):
#         super(PatchMerging, self).__init__(**kwargs)
#         self.input_resolution = input_resolution
#         self.dim = dim
#         self.reduction = tf.keras.layers.Dense(2 * dim, use_bias=False)
#         self.norm = tf.keras.layers.LayerNormalization()

#     def call(self, x):
#         H, W = self.input_resolution
#         x = tf.reshape(x, (-1, H, W, self.dim))
#         x0 = x[:, 0::2, 0::2, :]
#         x1 = x[:, 1::2, 0::2, :]
#         x2 = x[:, 0::2, 1::2, :]
#         x3 = x[:, 1::2, 1::2, :]
#         x = tf.concat([x0, x1, x2, x3], axis=-1)

#         x = self.norm(x)
#         x = self.reduction(x)
#         return x

# class SwinTransformer(tf.keras.Model):
#     def __init__(self, input_shape=(224, 224, 3), num_classes=9, **kwargs):
#         super(SwinTransformer, self).__init__(**kwargs)

#         # Initial patch embedding with Conv2D and downsampling
#         self.patch_embed = tf.keras.layers.Conv2D(filters=96, kernel_size=4, strides=4, padding='same')
#         self.pos_drop = tf.keras.layers.Dropout(0.0)

#         # Calculate initial resolution after patch embedding (downsampling by factor of 4)
#         self.input_resolution = (input_shape[0] // 4, input_shape[1] // 4)  # 56x56 if input shape is 224x224

#         # Stage 1
#         self.stage1 = SwinTransformerBlock(dim=96, num_heads=3, window_size=7, input_resolution=self.input_resolution)
#         self.merge1 = PatchMerging(input_resolution=self.input_resolution, dim=96)

#         # Calculate new resolution after first merging
#         stage2_resolution = (self.input_resolution[0] // 2, self.input_resolution[1] // 2)  # 28x28 if input is 224x224
#         self.stage2 = SwinTransformerBlock(dim=192, num_heads=6, window_size=7, input_resolution=stage2_resolution)
#         self.merge2 = PatchMerging(input_resolution=stage2_resolution, dim=192)

#         # Calculate new resolution after second merging
#         stage3_resolution = (stage2_resolution[0] // 2, stage2_resolution[1] // 2)  # 14x14 if input is 224x224
#         self.stage3 = SwinTransformerBlock(dim=384, num_heads=12, window_size=7, input_resolution=stage3_resolution)
#         self.merge3 = PatchMerging(input_resolution=stage3_resolution, dim=384)

#         # Calculate new resolution after third merging
#         stage4_resolution = (stage3_resolution[0] // 2, stage3_resolution[1] // 2)  # 7x7 if input is 224x224
#         self.stage4 = SwinTransformerBlock(dim=768, num_heads=24, window_size=7, input_resolution=stage4_resolution)

#         # Final layers
#         self.global_avg_pool = tf.keras.layers.GlobalAveragePooling2D()
#         self.head = tf.keras.layers.Dense(num_classes, activation="softmax")

#     def call(self, x, training=False):
#       # Patch embedding and positional dropout
#       x = self.patch_embed(x)
#       x = self.pos_drop(x, training=training)

#       # Dynamically get shape to handle None in batch size
#       B, H, W, C = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2], tf.shape(x)[3]

#       # Reshape (flatten spatial dimensions H, W into sequence dimension L)
#       x = tf.reshape(x, (B, H * W, C))  # Shape: (B, L, C)

#       # Forward through each Swin Transformer stage and merging
#       x = self.stage1(x)
#       x = self.merge1(x)

#       x = self.stage2(x)
#       x = self.merge2(x)

#       x = self.stage3(x)
#       x = self.merge3(x)

#       x = self.stage4(x)

#       # Reshape back to (B, H, W, C) for pooling
#       x = tf.reshape(x, (B, H // 32, W // 32, C * 2))

#       # Final pooling and dense layer for classification
#       x = self.global_avg_pool(x)
#       x = self.head(x)

#       return x


# def create_resnet_swin_model(input_shape=(224, 224, 3), num_classes=9):
#     resnet_input = Input(shape=input_shape)
#     resnet = ResNet50(include_top=False, weights="imagenet", input_tensor=resnet_input)

#     # Use Conv2DTranspose or UpSampling2D to upsample ResNet output to match Swin input requirements
#     upsampled_output = Conv2DTranspose(96, kernel_size=(3, 3), strides=(28, 28), padding='same')(resnet.output)
#     swin_input = Reshape((224, 224, 96))(upsampled_output)  # Adjust to (224, 224, 96)

#     swin_transformer = SwinTransformer(input_shape=(224, 224, 96), num_classes=num_classes)
#     swin_output = swin_transformer(swin_input)

#     model = Model(inputs=resnet_input, outputs=swin_output)
#     return model

# model = create_resnet_swin_model(input_shape=(240, 240, 3), num_classes=9)
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# model.summary()

# %%
# import tensorflow as tf

# # MLP Layer
# class MLP(tf.keras.layers.Layer):
#     def __init__(self, in_features, hidden_features=None, out_features=None, activation=tf.nn.gelu, dropout_rate=0.0):
#         super(MLP, self).__init__()
#         self.hidden_features = hidden_features or in_features
#         self.out_features = out_features or in_features
#         self.activation = activation
#         self.fc1 = tf.keras.layers.Dense(self.hidden_features)
#         self.act = tf.keras.layers.Activation(self.activation)
#         self.drop1 = tf.keras.layers.Dropout(dropout_rate)
#         self.fc2 = tf.keras.layers.Dense(self.out_features)
#         self.drop2 = tf.keras.layers.Dropout(dropout_rate)

#     def call(self, x, training=False):
#         x = self.fc1(x)
#         x = self.act(x)
#         x = self.drop1(x, training=training)
#         x = self.fc2(x)
#         x = self.drop2(x, training=training)
#         return x

# # Patch Embedding Layer
# class PatchEmbedding(tf.keras.layers.Layer):
#     def __init__(self, embed_dim=96, patch_size=4):
#         super(PatchEmbedding, self).__init__()
#         self.embed_dim = embed_dim
#         self.patch_size = patch_size
#         self.proj = tf.keras.layers.Conv2D(embed_dim, kernel_size=patch_size, strides=patch_size)

#     def call(self, x):
#         x = self.proj(x)
#         return tf.reshape(x, [tf.shape(x)[0], -1, self.embed_dim])

# # Window-based Multi-Head Self-Attention (W-MSA)
# class WindowAttention(tf.keras.layers.Layer):
#     def __init__(self, dim, num_heads, window_size, dropout_rate=0.0):
#         super(WindowAttention, self).__init__()
#         self.dim = dim
#         self.num_heads = num_heads
#         self.window_size = window_size
#         self.scale = (dim // num_heads) ** -0.5
#         self.qkv = tf.keras.layers.Dense(dim * 3)
#         self.proj = tf.keras.layers.Dense(dim)
#         self.attn_dropout = tf.keras.layers.Dropout(dropout_rate)
#         self.proj_dropout = tf.keras.layers.Dropout(dropout_rate)

#     def call(self, x):
#         B_, N, C = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
#         qkv = self.qkv(x)
#         qkv = tf.reshape(qkv, (B_, N, 3, self.num_heads, C // self.num_heads))
#         qkv = tf.transpose(qkv, perm=[2, 0, 3, 1, 4])
#         q, k, v = qkv[0], qkv[1], qkv[2]
#         q = q * self.scale
#         attn = tf.matmul(q, k, transpose_b=True)
#         attn = tf.nn.softmax(attn, axis=-1)
#         attn = self.attn_dropout(attn)
#         x = tf.matmul(attn, v)
#         x = tf.transpose(x, perm=[0, 2, 1, 3])
#         x = tf.reshape(x, (B_, N, C))
#         x = self.proj(x)
#         x = self.proj_dropout(x)
#         return x

# # Swin Transformer Block
# class SwinTransformerBlock(tf.keras.layers.Layer):
#     def __init__(self, dim, num_heads, window_size, shift_size=0, mlp_ratio=4., dropout_rate=0.0):
#         super(SwinTransformerBlock, self).__init__()
#         self.dim = dim
#         self.num_heads = num_heads
#         self.window_size = window_size
#         self.shift_size = shift_size
#         self.norm1 = tf.keras.layers.LayerNormalization(epsilon=1e-5)
#         self.attn = WindowAttention(dim, num_heads, window_size, dropout_rate=dropout_rate)
#         self.drop_path = tf.keras.layers.Dropout(dropout_rate)
#         self.norm2 = tf.keras.layers.LayerNormalization(epsilon=1e-5)
#         self.mlp = MLP(in_features=dim, hidden_features=int(dim * mlp_ratio), dropout_rate=dropout_rate)

#     def call(self, x):
#         H, W = int(tf.math.sqrt(tf.cast(tf.shape(x)[1], tf.float32))), int(tf.math.sqrt(tf.cast(tf.shape(x)[1], tf.float32)))
#         B, L, C = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
#         tf.debugging.assert_equal(L, H * W, message="Input feature has wrong size")

#         x = tf.reshape(x, (B, H, W, C))
#         x = self.norm1(x)

#         # Shifting if shift_size > 0
#         if self.shift_size > 0:
#             x = tf.roll(x, shift=[-self.shift_size, -self.shift_size], axis=[1, 2])

#         x_windows = tf.image.extract_patches(x, [1, self.window_size, self.window_size, 1],
#                                              [1, self.window_size, self.window_size, 1],
#                                              rates=[1, 1, 1, 1], padding='VALID')
#         x_windows = tf.reshape(x_windows, [-1, self.window_size * self.window_size, C])

#         attn_windows = self.attn(x_windows)
#         attn_windows = tf.reshape(attn_windows, [B, H // self.window_size, W // self.window_size,
#                                                  self.window_size, self.window_size, C])
#         x = tf.reshape(attn_windows, (B, H, W, C))

#         # Reversing shift
#         if self.shift_size > 0:
#             x = tf.roll(x, shift=[self.shift_size, self.shift_size], axis=[1, 2])

#         x = tf.reshape(x, (B, L, C))
#         x = x + self.drop_path(self.mlp(self.norm2(x)))
#         return x

# # Patch Merging
# class PatchMerging(tf.keras.layers.Layer):
#     def __init__(self, input_resolution, dim):
#         super(PatchMerging, self).__init__()
#         self.input_resolution = input_resolution
#         self.dim = dim
#         self.reduction = tf.keras.layers.Dense(dim * 2, use_bias=False)
#         self.norm = tf.keras.layers.LayerNormalization()

#     def call(self, x):
#         H, W = self.input_resolution
#         B, L, C = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
#         tf.debugging.assert_equal(L, H * W, message="Input feature has wrong size")

#         x = tf.reshape(x, (B, H, W, C))
#         x0 = x[:, 0::2, 0::2, :]
#         x1 = x[:, 1::2, 0::2, :]
#         x2 = x[:, 0::2, 1::2, :]
#         x3 = x[:, 1::2, 1::2, :]
#         x = tf.concat([x0, x1, x2, x3], axis=-1)

#         x = self.norm(x)
#         x = tf.reshape(x, (B, -1, 4 * C))
#         x = self.reduction(x)
#         return x

# # Assemble the Swin Transformer model
# def build_swin_transformer(input_shape=(224, 224, 3), num_classes=10):
#     inputs = tf.keras.Input(shape=input_shape)
#     x = PatchEmbedding(embed_dim=96)(inputs)

#     # First stage
#     x = SwinTransformerBlock(dim=96, num_heads=3, window_size=7)(x)
#     x = PatchMerging(input_resolution=(56, 56), dim=96)(x)

#     # Additional stages can be added similarly
#     x = tf.keras.layers.GlobalAveragePooling1D()(x)
#     outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

#     model = tf.keras.Model(inputs, outputs)
#     return model

# # Instantiate and compile the model
# model = build_swin_transformer()
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# model.summary()

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2DTranspose, Flatten, Dropout, Dense, GlobalAveragePooling1D
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import LearningRateScheduler

# Define MLP Layer
class MLP(tf.keras.layers.Layer):
    def __init__(self, in_features, hidden_features=None, out_features=None, activation=tf.nn.gelu, dropout_rate=0.0):
        super(MLP, self).__init__()
        self.hidden_features = hidden_features or in_features
        self.out_features = out_features or in_features
        self.activation = activation
        self.fc1 = tf.keras.layers.Dense(self.hidden_features)
        self.act = tf.keras.layers.Activation(self.activation)
        self.drop1 = tf.keras.layers.Dropout(dropout_rate)
        self.fc2 = tf.keras.layers.Dense(self.out_features)
        self.drop2 = tf.keras.layers.Dropout(dropout_rate)

    def call(self, x, training=False):
        x = self.fc1(x)
        x = self.act(x)
        x = self.drop1(x, training=training)
        x = self.fc2(x)
        x = self.drop2(x, training=training)
        return x

# Define Patch Embedding Layer
class PatchEmbedding(tf.keras.layers.Layer):
    def __init__(self, embed_dim=96, patch_size=4):
        super(PatchEmbedding, self).__init__()
        self.embed_dim = embed_dim
        self.patch_size = patch_size
        self.proj = tf.keras.layers.Conv2D(embed_dim, kernel_size=patch_size, strides=patch_size)

    def call(self, x):
        x = self.proj(x)
        return tf.reshape(x, [tf.shape(x)[0], -1, self.embed_dim])

# Define WindowAttention Layer
class WindowAttention(tf.keras.layers.Layer):
    def __init__(self, dim, num_heads, window_size, dropout_rate=0.0):
        super(WindowAttention, self).__init__()
        self.dim = dim
        self.num_heads = num_heads
        self.window_size = window_size
        self.scale = (dim // num_heads) ** -0.5
        self.qkv = tf.keras.layers.Dense(dim * 3)
        self.proj = tf.keras.layers.Dense(dim)
        self.attn_dropout = tf.keras.layers.Dropout(dropout_rate)
        self.proj_dropout = tf.keras.layers.Dropout(dropout_rate)

    def call(self, x):
        B, N, C = tf.shape(x)[0], tf.shape(x)[1], tf.shape(x)[2]
        qkv = self.qkv(x)
        qkv = tf.reshape(qkv, (B, N, 3, self.num_heads, C // self.num_heads))
        qkv = tf.transpose(qkv, perm=[2, 0, 3, 1, 4])
        q, k, v = qkv[0], qkv[1], qkv[2]
        q = q * self.scale
        attn = tf.nn.softmax(tf.matmul(q, k, transpose_b=True), axis=-1)
        attn = self.attn_dropout(attn)
        x = tf.matmul(attn, v)
        x = tf.transpose(x, perm=[0, 2, 1, 3])
        x = tf.reshape(x, (B, N, C))
        x = self.proj(x)
        x = self.proj_dropout(x)
        return x

# Define Swin Transformer Block
class SwinTransformerBlock(tf.keras.layers.Layer):
    def __init__(self, dim, num_heads, window_size, shift_size=0, mlp_ratio=4., dropout_rate=0.0):
        super(SwinTransformerBlock, self).__init__()
        self.dim = dim
        self.num_heads = num_heads
        self.window_size = window_size
        self.shift_size = shift_size
        self.norm1 = tf.keras.layers.LayerNormalization(epsilon=1e-5)
        self.attn = WindowAttention(dim, num_heads, window_size, dropout_rate)
        self.norm2 = tf.keras.layers.LayerNormalization(epsilon=1e-5)
        self.mlp = MLP(in_features=dim, hidden_features=int(dim * mlp_ratio), dropout_rate=dropout_rate)

    def call(self, x):
        shortcut = x
        x = self.norm1(x)
        x = self.attn(x)
        x = x + shortcut
        x = self.norm2(x)
        x = self.mlp(x)
        return x

# %%
# Define the ResNet-Swin Transformer Model
def create_resnet_swin_model(input_shape, num_classes):
    # Load ResNet50 without the top layer
    resnet = ResNet50(include_top=False, weights="imagenet", input_shape=input_shape)
    x = resnet.output

    # Upsample ResNet output to match the Swin input size
    upsampled_output = Conv2DTranspose(96, kernel_size=(4, 4), strides=(4, 4), padding='same')(x)

    # Add Patch Embedding layer
    swin_input = PatchEmbedding(embed_dim=96)(upsampled_output)

    # Add Swin Transformer block
    swin_block = SwinTransformerBlock(dim=96, num_heads=3, window_size=7)
    swin_output = swin_block(swin_input)

    # Add Global Average Pooling and output layer
    x = GlobalAveragePooling1D()(swin_output)
    outputs = Dense(num_classes, activation='softmax')(x)

    # Create the final model
    model = Model(inputs=resnet.input, outputs=outputs)
    return model

# Instantiate and compile the model
model = create_resnet_swin_model(input_shape=(32, 32, 3), num_classes=10)

# Define an adaptive learning rate scheduler
def lr_schedule(epoch, lr):
    if epoch < 5:
        return lr
    elif epoch < 10:
        return lr * 0.1
    else:
        return lr * 0.01

# Compile the model
sgd = SGD(learning_rate=1e-2, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

# Learning rate scheduler callback
lr_callback = LearningRateScheduler(lr_schedule)

# Print the model summary
model.summary()
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_pad (ZeroPadding2D) │ (None, 38, 38, 3)      │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 16, 16, 64)     │          9,472 │ conv1_pad[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Paths
dataset_path = '/content/drive/MyDrive/My Documents/final datset'
train_path = 'Dataset_splits/train'
valid_path = 'Dataset_splits/valid'
test_path = 'Dataset_splits/test'

# Create directories for train, valid, and test splits
os.makedirs(train_path, exist_ok=True)
os.makedirs(valid_path, exist_ok=True)
os.makedirs(test_path, exist_ok=True)

classes = [d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))]

for cls in classes:
    class_path = os.path.join(dataset_path, cls)
    images = [os.path.join(class_path, f) for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]

    # Split images into train, valid, and test sets
    train_imgs, temp_imgs = train_test_split(images, test_size=0.30, random_state=42)  # 75% train, 15% valid + 15% test
    valid_imgs, test_imgs = train_test_split(temp_imgs, test_size=0.50, random_state=42)  # 50% of the remaining 30% = 15% valid, 15% test

    # Create class directories in train, valid, and test splits
    os.makedirs(os.path.join(train_path, cls), exist_ok=True)
    os.makedirs(os.path.join(valid_path, cls), exist_ok=True)
    os.makedirs(os.path.join(test_path, cls), exist_ok=True)

    # Copy images to respective directories
    for img in train_imgs:
        shutil.copy(img, os.path.join(train_path, cls))
    for img in valid_imgs:
        shutil.copy(img, os.path.join(valid_path, cls))
    for img in test_imgs:
        shutil.copy(img, os.path.join(test_path, cls))

print("Dataset splitting complete!")
# Out:
# Dataset splitting complete!

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Define the path to your dataset
train_data_dir = '/content/Dataset_splits/train'
validation_data_dir = '/content/Dataset_splits/valid'
weights_dir = '/content/model_weights/'  # Directory to save weights

# Create the directory if it doesn't exist
if not os.path.exists(weights_dir):
    os.makedirs(weights_dir)

# Define image dimensions and batch size
img_width, img_height = 224, 224
batch_size = 4

# Data augmentation for training set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    brightness_range=[0.8, 1.2]
)

# Rescaling for validation set
test_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    brightness_range=[0.8, 1.2]
    )

# Load the training data
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)

# Load the validation data
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2942 images belonging to 9 classes.
# Found 633 images belonging to 9 classes.

# %%
checkpoint = ModelCheckpoint(
    filepath=os.path.join(weights_dir, 'weights_epoch_{epoch:02d}.weights.h5'),
    save_weights_only=True,  # Only save the weights
    save_freq='epoch'    # Save after every epoch
)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_pad (ZeroPadding2D) │ (None, 38, 38, 3)      │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 16, 16, 64)     │          9,472 │ conv1_pad[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Resize images to 28x28
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img

x_train = [img_to_array(array_to_img(img).resize((32, 32))) for img in x_train]
x_test = [img_to_array(array_to_img(img).resize((32, 32))) for img in x_test]

x_train = np.array(x_train)
x_test = np.array(x_test)

# Normalize pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode labels
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model.fit(
       x_train,
       y_train,
       batch_size=32,
       epochs=1,
       validation_data=(x_test, y_test),
       callbacks=[checkpoint, lr_callback]
   )
# Out:
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 119s 48ms/step - accuracy: 0.5134 - loss: 1.3901 - val_accuracy: 0.5769 - val_loss: 1.3513 - learning_rate: 0.0100

# %%
model.fit(
       x_train,
       y_train,
       batch_size=32,
       epochs=5,
       validation_data=(x_test, y_test),
       callbacks=[checkpoint, lr_callback]
   )
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 52s 34ms/step - accuracy: 0.7335 - loss: 0.7833 - val_accuracy: 0.6279 - val_loss: 1.1481 - learning_rate: 0.0100
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 33ms/step - accuracy: 0.7945 - loss: 0.6144 - val_accuracy: 0.6486 - val_loss: 1.0630 - learning_rate: 0.0100
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 34ms/step - accuracy: 0.8308 - loss: 0.5032 - val_accuracy: 0.7528 - val_loss: 0.7654 - learning_rate: 0.0100
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 50s 32ms/step - accuracy: 0.8635 - loss: 0.4120 - val_accuracy: 0.6856 - val_loss: 1.0659 - learning_rate: 0.0100
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 32ms/step - accuracy: 0.8841 - loss: 0.3461 - val_accuracy: 0.7764 - val_loss: 0.6951 - learning_rate: 0.0100
